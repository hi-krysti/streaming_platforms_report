# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
disney_data = pd.read_csv('disney_plus_titles.csv')


hulu_data = pd.read_csv('hulu_titles.csv')


netflix_data = pd.read_csv('netflix_titles.csv')

# %%
from sqlalchemy import create_engine


db_connection_str = 'postgresql://postgres:hellosql@localhost:5432/amazon_prime_titles'
db_connection = create_engine(db_connection_str)


amazon_data = pd.read_sql('SELECT * FROM amazon_prime_titles', con=db_connection)

# %%
amazon_data.head()
# Out:
#   show_id   type                 title        director  \
# 0      s1  Movie   The Grand Seduction    Don McKellar
# 1      s2  Movie  Take Care Good Night    Girish Joshi
# 2      s3  Movie  Secrets of Deception     Josh Webber
# 3      s4  Movie    Pink: Staying True  Sonia Anderson
# 4      s5  Movie         Monster Maker    Giles Foster
#
#                                                 cast         country  \
# 0     Brendan Gleeson, Taylor Kitsch, Gordon Pinsent          Canada
# 1   Mahesh Manjrekar, Abhay Mahajan, Sachin Khedekar           India
# 2  Tom Sizemore, Lorenzo Lamas, Robert LaSardo, R...   United States
# 3  Interviews with: Pink, Adele, Beyoncé, Britney...   United States
# 4  Harry Dean Stanton, Kieran O'Brien, George Cos...  United Kingdom
#
#        date_added  release_year rating duration                listed_in  \
# 0  March 30, 2021          2014   None  113 min            Comedy, Drama
# ...

# %%
disney_data.head()
# Out:
#   show_id     type                                             title  \
# 0      s1    Movie  Duck the Halls: A Mickey Mouse Christmas Special
# 1      s2    Movie                            Ernest Saves Christmas
# 2      s3    Movie                      Ice Age: A Mammoth Christmas
# 3      s4    Movie                        The Queen Family Singalong
# 4      s5  TV Show                             The Beatles: Get Back
#
#                             director  \
# 0  Alonso Ramirez Ramos, Dave Wasson
# 1                        John Cherry
# 2                       Karen Disher
# 3                    Hamish Hamilton
# 4                                NaN
#
#                                                 cast        country  \
# 0  Chris Diamantopoulos, Tony Anselmo, Tress MacN...            NaN
# 1           Jim Varney, Noelle Parker, Douglas Seale            NaN
# 2  Raymond Albert Romano, John Leguizamo, Denis L...  United States
# ...

# %%
hulu_data.head()
# Out:
#   show_id   type                           title director  cast country  \
# 0      s1  Movie  Ricky Velez: Here's Everything      NaN   NaN     NaN
# 1      s2  Movie                    Silent Night      NaN   NaN     NaN
# 2      s3  Movie                    The Marksman      NaN   NaN     NaN
# 3      s4  Movie                            Gaia      NaN   NaN     NaN
# 4      s5  Movie                        Settlers      NaN   NaN     NaN
#
#          date_added  release_year rating duration                  listed_in  \
# 0  October 24, 2021          2021  TV-MA      NaN           Comedy, Stand Up
# 1  October 23, 2021          2020    NaN   94 min     Crime, Drama, Thriller
# 2  October 23, 2021          2021  PG-13  108 min           Action, Thriller
# 3  October 22, 2021          2021      R   97 min                     Horror
# 4  October 22, 2021          2021    NaN  104 min  Science Fiction, Thriller
#
#                                          description
# ...

# %%
netflix_data.head()
# Out:
#   show_id     type                  title         director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water              NaN
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans              NaN
# 4      s5  TV Show           Kota Factory              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                NaN            NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
# ...

# %%
hulu_data.isnull().sum()
# Out:
# show_id            0
# type               0
# title              0
# director        3070
# cast            3073
# country         1453
# date_added        28
# release_year       0
# rating           520
# duration         479
# listed_in          0
# description        4
# dtype: int64

# %%
amazon_data.isnull().sum()
# Out:
# show_id            0
# type               0
# title              0
# director        2082
# cast            1233
# country         8996
# date_added      9513
# release_year       0
# rating           337
# duration           0
# listed_in          0
# description        0
# dtype: int64

# %%
disney_data.isnull().sum()
# Out:
# show_id           0
# type              0
# title             0
# director        473
# cast            190
# country         219
# date_added        3
# release_year      0
# rating            3
# duration          0
# listed_in         0
# description       0
# dtype: int64

# %%
netflix_data.isnull().sum()
# Out:
# show_id            0
# type               0
# title              0
# director        2634
# cast             825
# country          831
# date_added        10
# release_year       0
# rating             4
# duration           3
# listed_in          0
# description        0
# dtype: int64

# %%
hulu_data["listed_in"].nunique()
# Out:
# 442

# %%
hulu_data.shape
# Out:
# (3073, 12)

# %%
amazon_data = pd.read_sql('SELECT * FROM amazon_prime_titles', con=db_connection)
amazon_data.shape
# Out:
# (9668, 12)

# %%
pd.isna(amazon_data.date_added).mean()
# Out:
# 0.9839677285891602

# %%
all_data = pd.concat([disney_data, hulu_data, netflix_data])

# %%
filtered_data = all_data[all_data['release_year'] > 2000]

# %%
count_after_2000 = filtered_data.shape[0]

# %%
total_titles = all_data.shape[0]

# %%
over_half_after_2000 = count_after_2000 > (total_titles / 2)

# %%
## When was most content on the platforms released? ##
## Assumption was most content was released after the year 2000 ##

labels = ['Released After 2000', 'Released Before 2000']
sizes = [count_after_2000, total_titles - count_after_2000]
colors = ['lightcoral', 'lightskyblue']

plt.pie(sizes, labels=labels, colors=colors, autopct='%1.1f%%', startangle=140)
plt.title('Distribution of Release Years')
plt.show()

# %%
release_counts = filtered_data['release_year'].value_counts().sort_index()

# %%
## Number of releases for years after 2000 ##

plt.figure(figsize=(12, 6))
sns.barplot(x=release_counts.index, y=release_counts.values, color='skyblue')
plt.title('Number of Releases for Each Year (After 2000)')
plt.xlabel('Release Year')
plt.ylabel('Number of Releases')
plt.xticks(rotation=45)
plt.show()

# %%
release_counts = all_data['release_year'].value_counts().sort_index()

# %%
## Total releases for each year for all platforms ##

plt.figure(figsize=(20, 6))
sns.barplot(x=release_counts.index, y=release_counts.values, color='lightgreen')  
plt.title('Number of Releases for Each Year')
plt.xlabel('Release Year')
plt.ylabel('Number of Releases')
plt.xticks(rotation=90)
plt.show()

## The approach we took was to look at the data in a few different ways to really understand when the bulk of it was released. This last chart expands on that and shows that from the data, 2019 had the most releases overall ##

# %%
## Which streaming platform has the most 'shows', which has the longest-running shows (most seasons) ##
## Number of seasons for Disney shows, assumption was Disney had the most long-running shows ##

tv_shows_data = disney_data[disney_data['type'] == 'TV Show'].copy()  


tv_shows_data['num_seasons'] = tv_shows_data['duration'].str.extract('(\d+)').astype(float)


plt.figure(figsize=(10, 6))
sns.countplot(x='num_seasons', data=tv_shows_data, palette='viridis')  
plt.title('Number of Seasons for Disney+ TV Shows')
plt.xlabel('Number of Seasons')
plt.ylabel('Count')
plt.show()

# %%
## Number of seasons for all streaming platforms, which one has the most 'TV Shows' ##
## Which platform has TV Shows with the most seasons ##

hulu_data['platform'] = 'Hulu'
disney_data['platform'] = 'Disney+'
netflix_data['platform'] = 'Netflix'
amazon_data['platform'] = 'Amazon Prime'

disney_tv_shows_data = disney_data[disney_data['type'] == 'TV Show'].copy()
disney_tv_shows_data['num_seasons'] = disney_tv_shows_data['duration'].str.extract('(\d+)').astype(float)

netflix_tv_shows_data = netflix_data[netflix_data['type'] == 'TV Show'].copy()
netflix_tv_shows_data['num_seasons'] = netflix_tv_shows_data['duration'].str.extract('(\d+)').astype(float)

hulu_tv_shows_data = hulu_data[hulu_data['type'] == 'TV Show'].copy()
hulu_tv_shows_data['num_seasons'] = hulu_tv_shows_data['duration'].str.extract('(\d+)').astype(float)

amazon_tv_shows_data = amazon_data[amazon_data['type'] == 'TV Show'].copy()
amazon_tv_shows_data['num_seasons'] = amazon_tv_shows_data['duration'].str.extract('(\d+)').astype(float)

all_tv_shows_data = pd.concat([disney_tv_shows_data, netflix_tv_shows_data, hulu_tv_shows_data, amazon_tv_shows_data],
                              ignore_index=True)

plt.figure(figsize=(12, 8))
sns.countplot(x='num_seasons', hue='platform', data=all_tv_shows_data, palette='viridis')
plt.title('Number of Seasons for TV Shows on Streaming Platforms')
plt.xlabel('Number of Seasons')
plt.ylabel('Count')
plt.show()

plt.figure(figsize=(10, 6))
sns.countplot(x='platform', data=all_tv_shows_data, palette='viridis')
plt.title('Number of TV Shows for Each Streaming Platform')
plt.xlabel('Platform')
plt.ylabel('Count')
plt.show()

## We again took the approach of looking at the data and expanding on it in a few ways. Our initial assumption was wrong, Netflix has the most shows and the longest running shows ##

# %%
## Which month is most common for content to be released? ## 
## Assumption is Sep and Oct are the most popular release months ##

hulu_data['platform'] = 'Hulu'
disney_data['platform'] = 'Disney+'
netflix_data['platform'] = 'Netflix'
amazon_data['platform'] = 'Amazon Prime'

all_data = pd.concat([hulu_data, disney_data, netflix_data, amazon_data], ignore_index=True)

all_data['date_added'] = pd.to_datetime(all_data['date_added'], errors='coerce')

all_data['release_month'] = all_data['date_added'].dt.month_name()

plt.figure(figsize=(12, 8))
sns.countplot(x='release_month', hue='platform', data=all_data, palette='viridis', dodge=True)
plt.title('Number of Releases by Month for Streaming Platforms')
plt.xlabel('Release Month')
plt.ylabel('Number of Releases')
plt.show()

# %%
## Looking at the trends of release months over the years to expand on the data ##
all_data['release_year'] = all_data['date_added'].dt.year

plt.figure(figsize=(15, 8))
sns.countplot(x='release_month', hue='release_year', data=all_data, palette='deep', dodge=True)
plt.title('Number of Releases by Month and Year for Streaming Platforms')
plt.xlabel('Release Month')
plt.ylabel('Number of Releases')
plt.legend(title='Release Year', bbox_to_anchor=(1.05, 1), loc='upper left')
plt.show()

# %%
## We wanted a clearer visualization to show the month with most releases ##
counts = all_data['release_month'].value_counts()

fig, ax = plt.subplots(figsize=(15, 8))

ax.bar(counts.index, counts, color='skyblue', edgecolor='black')

ax.set_xlabel('Release Month')

ax.set_ylabel('Number of Releases')

ax.set_title('Histogram of Releases by Month for Streaming Platforms')

plt.show()

## Again our assumption was wrong, November is by far the most popular month to release content across all platforms ##

# %%
##  What are the most popular ratings among the 4 streaming platforms?

## Prediction - We think that the majority of movies/shows on all platforms will be rated - 13+, TV-14, ALL, TV-PG, TV-G,
# P-13, PG, G, ALL_AGES since those ratings would be appropriate for the majority of viewers.

# %% [markdown]
# # Netflix

# %%
netflix_data['rating'].unique()
# Out:
# array(['PG-13', 'TV-MA', 'PG', 'TV-14', 'TV-PG', 'TV-Y', 'TV-Y7', 'R',
#        'TV-G', 'G', 'NC-17', '74 min', '84 min', '66 min', 'NR', nan,
#        'TV-Y7-FV', 'UR'], dtype=object)

# %%
# VISUAL INCLUDING ALL RATINGS FOR NETFLIX (NOT ORDERED)
rating_order_netflix = ['PG-13', 'TV-MA', 'PG', 'TV-14', 'TV-PG', 'TV-Y', 'TV-Y7', 'R', 'TV-G', 'G', 'NC-17', 'NR', 'nan','TV-Y7-FV', 'UR']
sns.set(rc={'axes.titlesize':75,'axes.labelsize':35})
sns.set(font_scale=2)
sns.countplot(data=netflix_data, x='rating', order=rating_order_netflix).set(title='NETFLIX: Ratings of movies and TV shows')
# Out:
# [Text(0.5, 1.0, 'NETFLIX: Ratings of movies and TV shows')]

# %%
# CREATED NEW VISUAL WITH ONLY RATINGS THAT HAD VALUES AND PUT THEM IN DESCENDING ORDER
netflix_chart = sns.countplot(data=netflix_data, x='rating', order=['TV-MA', 'TV-14','TV-PG', 'R', 'PG-13', 'TV-Y7', 'TV-Y', 'PG', 'TV-G', 'NR', 'G']).set(title='NETFLIX: Ratings of movies and TV shows sorted in descending order')

# %% [markdown]
# # Amazon

# %%
amazon_data['rating'].unique()
# Out:
# array([None, '13+', 'ALL', '18+', 'R', 'TV-Y', 'TV-Y7', 'NR', '16+',
#        'TV-PG', '7+', 'TV-14', 'TV-NR', 'TV-G', 'PG-13', 'TV-MA', 'G',
#        'PG', 'NC-17', 'UNRATED', '16', 'AGES_16_', 'AGES_18_', 'ALL_AGES',
#        'NOT_RATE'], dtype=object)

# %%
amazon_chart = sns.countplot(data=amazon_data, x='rating', order=['13+', '16+', 'ALL', '18+', 'R', 'PG-13', '7+', 'PG', 'NR', 'TV-14', 'TV-PG', 'TV-NR', 'G', 'TV-G', 'TV-MA', 'TV-Y', 'TV-Y7', 'UNRATED']).axes.set_title('AMAZON: Ratings of movies and TV shows sorted in descending order')

# %% [markdown]
# # Hulu

# %%
hulu_data['rating'].unique()
# Out:
# array(['TV-MA', nan, 'PG-13', 'R', 'TV-14', 'PG', 'TV-PG', 'NOT RATED',
#        'G', 'TV-G', '2 Seasons', 'TV-Y', '93 min', '4 Seasons', 'TV-Y7',
#        '136 min', '91 min', '85 min', '98 min', '89 min', '94 min',
#        '86 min', '3 Seasons', '121 min', '88 min', '101 min', '1 Season',
#        '83 min', '100 min', '95 min', '92 min', '96 min', '109 min',
#        '99 min', '75 min', '87 min', '67 min', '104 min', '107 min',
#        '84 min', '103 min', '105 min', '119 min', '114 min', '82 min',
#        '90 min', '130 min', '110 min', '80 min', '6 Seasons', '97 min',
#        '111 min', '81 min', '49 min', '45 min', '41 min', '73 min',
#        '40 min', '36 min', '39 min', '34 min', '47 min', '65 min',
#        '37 min', '78 min', '102 min', '129 min', '115 min', '112 min',
#        'NR', '61 min', '106 min', '76 min', '77 min', '79 min', '157 min',
#        '28 min', '64 min', '7 min', '5 min', '6 min', '127 min',
# ...

# %%
hulu_chart = sns.countplot(data=hulu_data, x='rating', order=['TV-14', 'TV-MA', 'R','TV-PG', 'PG-13', 'TV-G', 'PG', 'TV-Y7', 'TV-Y', 'G' ]).set(title='HULU: Ratings of movies and TV shows sorted in descending order')

# %% [markdown]
# # Disney

# %%
disney_data['rating'].unique()
# Out:
# array(['TV-G', 'PG', 'TV-PG', nan, 'PG-13', 'TV-14', 'G', 'TV-Y7', 'TV-Y',
#        'TV-Y7-FV'], dtype=object)

# %%
disney_chart = sns.countplot(data=disney_data, x='rating', order=['TV-G', 'TV-PG', 'G', 'PG', 'TV-Y7', 'TV-14', 'PG-13', 'TV-Y', 'TV-Y7-FV']).set(title='DISNEY: Ratings of movies and TV shows sorted in descending order')

# %%
# Conclusion: Our prediction was accurate because all but one of the streaming platforms top rating for movies/shows 
# is what we predicted (13+, PG13, 14, G, ALL etc)

# Amazon - 13+ 
# Netflix - TV-MA, but second highest is TV-14 
# Hulu - TV-14 
# Disney - TV-G
